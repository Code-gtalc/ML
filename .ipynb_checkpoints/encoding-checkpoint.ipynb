# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df=pd.read_excel("Dataset.xlsx")

# %%
#Label encoding in gender column
le=LabelEncoder()
le.fit(df["Gender"])
df["Gender"]=le.transform(df["Gender"])
print(df)
# Out:
#    Student_ID  Gender Education_Level       City        Department
# 0        S001       1     High School  Bangalore  Computer Science
# 1        S002       0      Bachelor's    Chennai       Electronics
# 2        S003       0        Master's  Bangalore        Mechanical
# 3        S004       1             PhD     Mumbai  Computer Science
# 4        S005       1      Bachelor's      Delhi             Civil
# 5        S006       0     High School    Chennai       Electronics
# 6        S007       0        Master's  Hyderabad  Computer Science
# 7        S008       1      Bachelor's  Bangalore        Mechanical
# 8        S009       0             PhD      Delhi             Civil
# 9        S010       1        Master's       Pune       Electronics
# 10       S011       0      Bachelor's  Bangalore  Computer Science
# 11       S012       1     High School      Kochi             Civil
# 12       S013       0        Master's     Mumbai        Mechanical
# 13       S014       1             PhD  Hyderabad       Electronics
# 14       S015       0      Bachelor's       Pune  Computer Science

# %%
#Ordinal encoding in Education_Level column

education_order = ["High School", "Bachelors", "Masters", "PhD"]
df["Education_Level"] = pd.Categorical(df["Education_Level"], categories=education_order, ordered=True)
df["Education_Level"] = df["Education_Level"].cat.codes
print(df)
# Out:
#    Student_ID  Gender  Education_Level       City        Department
# 0        S001       1                0  Bangalore  Computer Science
# 1        S002       0               -1    Chennai       Electronics
# 2        S003       0               -1  Bangalore        Mechanical
# 3        S004       1                3     Mumbai  Computer Science
# 4        S005       1               -1      Delhi             Civil
# 5        S006       0                0    Chennai       Electronics
# 6        S007       0               -1  Hyderabad  Computer Science
# 7        S008       1               -1  Bangalore        Mechanical
# 8        S009       0                3      Delhi             Civil
# 9        S010       1               -1       Pune       Electronics
# 10       S011       0               -1  Bangalore  Computer Science
# 11       S012       1                0      Kochi             Civil
# 12       S013       0               -1     Mumbai        Mechanical
# 13       S014       1                3  Hyderabad       Electronics
# 14       S015       0               -1       Pune  Computer Science
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12840\202782204.py:4: Pandas4Warning: Constructing a Categorical with a dtype and values containing non-null entries not in that dtype's categories is deprecated and will raise in a future version.
#   df["Education_Level"] = pd.Categorical(df["Education_Level"], categories=education_order, ordered=True)

# %%
#Frequency encoding on City column

city_freq = df["City"].value_counts()
df["City"] = df["City"].map(city_freq)
print(df)
# Out:
#    Student_ID  Gender  Education_Level  City        Department
# 0        S001       1                0     4  Computer Science
# 1        S002       0               -1     2       Electronics
# 2        S003       0               -1     4        Mechanical
# 3        S004       1                3     2  Computer Science
# 4        S005       1               -1     2             Civil
# 5        S006       0                0     2       Electronics
# 6        S007       0               -1     2  Computer Science
# 7        S008       1               -1     4        Mechanical
# 8        S009       0                3     2             Civil
# 9        S010       1               -1     2       Electronics
# 10       S011       0               -1     4  Computer Science
# 11       S012       1                0     1             Civil
# 12       S013       0               -1     2        Mechanical
# 13       S014       1                3     2       Electronics
# 14       S015       0               -1     2  Computer Science

# %%
#One-hot encoding on Department column

df = pd.get_dummies(df, columns=["Department"], prefix="Dept")
print(df)
# Out:
#    Student_ID  Gender  Education_Level  City  Dept_Civil  \
# 0        S001       1                0     4       False
# 1        S002       0               -1     2       False
# 2        S003       0               -1     4       False
# 3        S004       1                3     2       False
# 4        S005       1               -1     2        True
# 5        S006       0                0     2       False
# 6        S007       0               -1     2       False
# 7        S008       1               -1     4       False
# 8        S009       0                3     2        True
# 9        S010       1               -1     2       False
# 10       S011       0               -1     4       False
# 11       S012       1                0     1        True
# 12       S013       0               -1     2       False
# 13       S014       1                3     2       False
# 14       S015       0               -1     2       False
#
#     Dept_Computer Science  Dept_Electronics  Dept_Mechanical
# 0                    True             False            False
# 1                   False              True            False
# 2                   False             False             True
# 3                    True             False            False
# 4                   False             False            False
# 5                   False              True            False
# 6                    True             False            False
# 7                   False             False             True
# 8                   False             False            False
# 9                   False              True            False
# 10                   True             False            False
# 11                  False             False            False
# 12                  False             False             True
# 13                  False              True            False
# 14                   True             False            False

# %%
df
# Out:
#    Student_ID  Gender  Education_Level  City  Dept_Civil  \
# 0        S001       1                0     4       False
# 1        S002       0               -1     2       False
# 2        S003       0               -1     4       False
# 3        S004       1                3     2       False
# 4        S005       1               -1     2        True
# 5        S006       0                0     2       False
# 6        S007       0               -1     2       False
# 7        S008       1               -1     4       False
# 8        S009       0                3     2        True
# 9        S010       1               -1     2       False
# 10       S011       0               -1     4       False
# 11       S012       1                0     1        True
# 12       S013       0               -1     2       False
# 13       S014       1                3     2       False
# 14       S015       0               -1     2       False
#
#     Dept_Computer Science  Dept_Electronics  Dept_Mechanical
# 0                    True             False            False
# 1                   False              True            False
# 2                   False             False             True
# 3                    True             False            False
# 4                   False             False            False
# 5                   False              True            False
# 6                    True             False            False
# 7                   False             False             True
# 8                   False             False            False
# 9                   False              True            False
# 10                   True             False            False
# 11                  False             False            False
# 12                  False             False             True
# 13                  False              True            False
# 14                   True             False            False
